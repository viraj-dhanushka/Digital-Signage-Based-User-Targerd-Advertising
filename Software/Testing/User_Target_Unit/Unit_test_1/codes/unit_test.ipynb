# %%
import unittest
import nbimporter
import age_gender_classification
import cv2
# Out:
# Importing Jupyter notebook from age_gender_classification.ipynb

# %%
class TestStringMethods(unittest.TestCase):

    def test_agegender(self):
        
        age_net, gender_net = age_gender_classification.initialize_caffe_model()
    
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_1.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(25, 32)', 'Female'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_2.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(4, 6)', 'Female'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_3.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(25, 32)', 'Female'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_4.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(48, 53)', 'Male'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_5.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(25, 32)', 'Female'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_6.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(25, 32)', 'Female'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_7.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(25, 32)','Female'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_8.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(8, 12)','Male'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_9.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(8, 12)','Male'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_10.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(8, 12)','Male'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_11.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(25, 32)','Female'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_12.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(25, 32)','Female'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_13.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(25, 32)','Female'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_14.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(8, 12)','Male'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_15.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(4, 6)','Male'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_16.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(25, 32)','Male'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_17.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(25, 32)','Male'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_18.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(25, 32)','Male'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_19.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(0, 2)','Male'))
        
        image = cv2.imread(r"E:\cs_life\ml_ai\age_gender_classification\codes\sample_photos\peop1_20.jpg")
        self.assertEqual(age_gender_classification.capture_loop(age_net, gender_net,image), ('(48, 53)','Male'))

# %%
 if __name__ == '__main__':
        unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# (25, 32)
# Female
# Test passed!
# (4, 6)
# Female
# Test passed!
# (25, 32)
# Female
# Test passed!
# (48, 53)
# Male
# Test passed!
# (25, 32)
# Female
# Test passed!
# (25, 32)
# Female
# Test passed!
# (25, 32)
# Female
# Test passed!
# (8, 12)
# Male
# Test passed!
# (8, 12)
# Male
# Test passed!
# (8, 12)
# Male
# Test passed!
# (25, 32)
# Female
# Test passed!
# (25, 32)
# Female
# Test passed!
# (25, 32)
# Female
# Test passed!
# (8, 12)
# Male
# Test passed!
# (4, 6)
# Male
# Test passed!
# (25, 32)
# Male
# Test passed!
# (25, 32)
# Male
# Test passed!
# (25, 32)
# Male
# Test passed!
# (0, 2)
# Male
# Test passed!
# (25, 32)
# Male
# Test passed!
# F
# ...
# FAIL: test_agegender (__main__.TestStringMethods)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-2-cffd17012218>", line 65, in test_agegender
# ...
